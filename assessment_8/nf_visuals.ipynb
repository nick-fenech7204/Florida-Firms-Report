# %%
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
municipality_df = pd.read_csv('../assessment_8/data/municipality_df.csv')
gdp_df = pd.read_csv('../assessment_8/data/gdp_df.csv')

# %%
miami = municipality_df[municipality_df['Municipality'] == 'Miami-Fort Lauderdale-West Palm Beach, FL Metro Area']
miami.shape
# Out:
# (63, 8)

# %%
fig = px.bar(miami, y='Amount_of_Firms', x='Firm_Sale_Amount')
fig.update_layout(
    xaxis_title="Firm Sale Amount",
    yaxis_title="Amount of Firms"
)
fig.update_layout(title="Firm Sale's vs Total Firms in Miami")
fig.show()

# %%
grouped_gender= miami.groupby('Ethnicity')['Amount_of_Firms'].mean()
grouped_gender

# %%
data = {
    'Ethnicity': ['Equally Hispanic/non-Hispanic', 'Hispanic', 'Non-Hispanic'],
    'Amount_of_Firms': [236, 5325, 12750],
}

df = pd.DataFrame(data)
fig, ax = plt.subplots()
bars = ax.barh(df['Ethnicity'], df['Amount_of_Firms'], color=['purple', 'green', 'blue'])
for i, v in enumerate(df['Amount_of_Firms']):
    ax.text(v + 159, i - 0.15, str(v), color='black')
ax.set_xlabel('Amount of Firms', fontweight = 'bold')
ax.set_ylabel('Ethnicity', fontweight='bold')
ax.set_title('Ethnicity in Miami Firms', fontweight='bold')
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.show()

# %%
pd.options.display.max_rows = 999
gdp_df.info()

# %%
miami_gdp = gdp_df[gdp_df['DATE'] == '2018-01-01']
miami_gdp
# Out:
#           DATE   Tampa_GDP   Miami_GDP  Orlando_GDP
# 17  2018-01-01  141091.139  319777.839   158969.547

# %%
miami_gdp = pd.DataFrame(data)
fig, ax = plt.subplots()
ax.bar(miami_gdp['City'], miami_gdp['GDP'])

ax.set_title('Florida Cities GDP in 2018')
ax.set_xlabel('City')
ax.set_ylabel('GDP in Millions (USD)')
plt.show()

# %%
city_sales = municipality_df.groupby('Firm_Sale_Amount')['Municipality'].sum().reset_index()
city_sales
# Out:
#         Firm_Sale_Amount                                       Municipality
# 0     $1,000,000 or more  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 1        $10,000-$24,999  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 2     $1,000,000 or more  Orlando-Kissimmee-Sanford, FL Metro AreaOrland...
# 3        $10,000-$24,999  Orlando-Kissimmee-Sanford, FL Metro AreaOrland...
# 4      $100,000-$249,999  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 5        $25,000-$49,999  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 6   $250,000 to $499,999  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 7      $250,000-$499,999  Orlando-Kissimmee-Sanford, FL Metro AreaOrland...
# 8          $5,000,$9,000  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 9          $5,000-$9,999  Orlando-Kissimmee-Sanford, FL Metro AreaOrland...
# 10       $50,000-$99,999  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 11     $500,000-$999,999  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 12      Less than $5,000  Miami-Fort Lauderdale-West Palm Beach, FL Metr...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.bar(city_sales['Municipality'], city_sales['Firm_Sale_Amount'])

ax.set_title('Firm Sales by City')
ax.set_xlabel('City')
ax.set_ylabel('Firm Sales (USD)')
plt.xticks(rotation=90)
plt.show()
